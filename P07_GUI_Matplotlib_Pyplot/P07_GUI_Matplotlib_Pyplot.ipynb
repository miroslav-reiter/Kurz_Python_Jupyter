# %% [markdown]
# # 🐍 Kurz Python Jupyter - 7. časť

# %% [markdown]
# Alt + 35, Shift + 3
# Win + . emoji
# emojipedia.org - https://emojipedia.org/snake/
#
# Pyplot, Matplolib, GUI, tkinter

# %% [markdown]
# # 01. Pyplot

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[-2,4,6,9,-11])
plt.title("Zavislost mojho veku od penazi")
plt.xlabel("X os")
plt.ylabel("Y os")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5])
plt.title("Zavislost mojho veku od penazi")
plt.xlabel("X os")
plt.ylabel("Y os")
plt.show()

# %%
import matplotlib.pyplot as plt
# RGB
# CMYK
# HSV, HSB, HSL
# p - pentauholnik, x - krizik, o - gulicka, d - (disc), s (square) - stvorec ^ - trojuholnik
# -- (dot) čiarkovaná, -., . , * 
plt.plot([1,2,3,4,5],[1,4,9,16,25], "yo")
plt.title("Zavislost mojho veku od penazi")
plt.xlabel("X os")
plt.ylabel("Y os")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0, 6, 0.5)
plt.plot(t, t, "yo", t, t**2,"rd", t, t**3, "gp", t, t**4, "b-.")
plt.title("Zavislost mojho veku od penazi")
plt.xlabel("X os")
plt.ylabel("Y os")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

skupiny = ["1. skupina", "2. skupina", "3. skupina"]
hodnoty = [1,10,100]

# default 6.4, 4.8 
plt.figure(figsize=(11.5,3.5))
# Cislo riadku, Cislo stlpca, index
# nrows, ncols, index
plt.subplot(1,4,1)
plt.bar(skupiny, hodnoty)
plt.subplot(1,4,2)
plt.plot(skupiny, hodnoty)
plt.subplot(1,4,3)
plt.scatter(skupiny, hodnoty)
plt.subplot(1,4,4)
plt.plot(skupiny, hodnoty)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Stredna hodnota/media
# Sigma smerodajna/standardna odchylka +- autobus
mi, sigma = 100, 20
x = mi + sigma * np.random.randn(10000)
n, bins, patches = plt.hist(x, 20, density = 1, facecolor="m", alpha = 0.8)

plt.xlabel("IQ")
plt.ylabel("Pravdepodobnosti")
plt.title("Histogram IQ")
plt.text(50, 0.015, r"$\mu\ = 100$")
plt.text(50, 0.0125, r"$\sigma\ = 20$")
plt.grid()
plt.show()

# %% [markdown]
# # GUI, tkinter

# %%
import tkinter

canvas = tkinter.Canvas()
canvas.pack()
canvas.create_text(120, 140, text="Hello World")
tkinter.mainloop()

# %%
import tkinter
import random

canvas = tkinter.Canvas()
canvas.pack()

for i in range(10):
    x = random.randint(0,300)
    y = random.randint(0,250)
    canvas.create_text(x, y, text="Hello World")
    
    
tkinter.mainloop()

# %%
import tkinter
import random

canvas = tkinter.Canvas()
canvas.pack()

canvas.create_rectangle(60,20,120,40)

# for i in range(10):
#     x = random.randint(0,300)
#     y = random.randint(0,250)
#     canvas.create_text(x, y, text="Hello World")
    
    
tkinter.mainloop()

# %%
import tkinter
import random

canvas = tkinter.Canvas()
canvas.pack()

for i in range(10):
    x = random.randint(10,100)
    y = random.randint(10,100)
    sirka, vyska = 200, 60
    canvas.create_rectangle(x, y, x + sirka, y + vyska, fill = "plum")
    
tkinter.mainloop()
