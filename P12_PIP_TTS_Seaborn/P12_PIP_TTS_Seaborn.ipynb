# %% [markdown]
# # 🐍 Kurz Python Jupyter - 12. časť

# %% [markdown]
# PIP (Package Installer for Python), TTS (Text to Speech), Seaborn (Vizualizácie, diagramy, grafy)
# TTS - pyttsx3 (Nevyžaduje internetové pripojenie)
# TTS - GTTS (Vyžaduje sa internetové pripojenie - Google prekladač)

# %%
# %pip uninstall cowsay

# %%
# %pip install --upgrade

# %%
a = 2
text = "textik"

# %%
# %pip freeze

# %%
# %pip install -r C://zoznam_balickov.txt

# %%
# %pip install  https://github.com/miroslav-reiter/Kurz_Python_Jupyter/blob/main/zoznam_balickov.txt

# %%
# %pip help

# %%
import pyttsx3

# sapi5 - windows
# nsss - mac os/linux
# espeak - lubovolny os/plaformu

engine = pyttsx3.init(driverName="sapi4")
rate = engine.getProperty("rate")
voices = engine.getProperty("voices")

print("Rychlost: ", rate)

engine.setProperty("rate", 150)
# 0 Muz, 1 Zena
engine.setProperty("voice", voices[0].id)
engine.say("Hello, i am future Python developer")
engine.runAndWait()

# %%
from gtts import gTTS

tts = gTTS("Hello, i am future Python developer")
tts.save("developer.mp3")

# %%
import seaborn as sns

kvety = sns.load_dataset("iris")

sns.lineplot(x = "sepal_length", y="sepal_width", data=kvety)
sns.set_style("dark")

# %%
import seaborn as sns

sns.set_theme()
tringelty = sns.load_dataset("tips")

sns.relplot(
    data = tringelty,
    x = "total_bill",
    y = "tip",
    col="time",
    hue="smoker",
    style="smoker",
    size="size"
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

paleta_farieb = sns.color_palette("PiYG", 8)
sns.palplot(paleta_farieb)
plt.show()
